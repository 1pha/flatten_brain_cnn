# %% [markdown]
# # Importing Lines

# %%
import os, sys

import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import train_test_split, KFold

sys.path.append(os.path.dirname(os.path.abspath(os.path.dirname('../utils/'))))
from utils.saving import *
from utils.load_data import *

# %% [markdown]
# # Load Data

# %%
CTYPE = 'multi'

X = loader.image()
y = loader.label(return_type=CTYPE)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=867.0), HTML(value='')))

# %%
SEED = 42
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=SEED)

# %%
trn_ds = TensorDataset(X_train, y_train)
tst_ds = TensorDataset(X_test, y_test)

BATCH = 16
trn_dl = DataLoader(trn_ds, batch_size=BATCH, shuffle=True)
tst_dl = DataLoader(tst_ds, batch_size=BATCH, shuffle=True)

# %% [markdown]
# # Build Model

# %%
from convnet_v2 import *

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
CTYPE = 'multi'
# model = ConvNet(ctype=CTYPE, flat_nodes=19200).to(device)
model = ConvNet(ctype=CTYPE).to(device)

# %%
weight = loader.weighting(y).to(device)

# %%
loss_fn = model.loss_fn(weight=weight)

LEARNING_RATE = 1e-2
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)

# %%
accuracy = model.accuracy

# %% [markdown]
# ## Debug

# %%
model
# Out:
# ConvNet(
#   (layer1): Sequential(
#     (0): Conv2d(6, 16, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.2, inplace=False)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer2): Sequential(
#     (0): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.2, inplace=False)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer3): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.2, inplace=False)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (fc1): Linear(in_features=1280, out_features=100, bias=True)
#   (fc2): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
for idx, (x, y) in enumerate(trn_dl):
    if idx < 3:
        x = x.to(device)
        print(model(x))
# Out:
# G:\My Drive\brain_data\workspace\Convolution_Models\convnet_v2.py:80: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   out = self.last_layer(out)
# tensor([[0.0651, 0.1147, 0.1349, 0.0750, 0.2063, 0.0698, 0.0677, 0.1174, 0.0847,
#          0.0644],
#         [0.0734, 0.1909, 0.1576, 0.0918, 0.1430, 0.0652, 0.0484, 0.0993, 0.0776,
#          0.0529],
#         [0.0805, 0.1304, 0.1414, 0.1135, 0.1424, 0.0875, 0.0601, 0.0856, 0.0810,
#          0.0775],
#         [0.1144, 0.1380, 0.1605, 0.0803, 0.1624, 0.1017, 0.0329, 0.0860, 0.0617,
#          0.0622],
#         [0.0746, 0.1752, 0.1343, 0.0969, 0.1592, 0.0627, 0.0645, 0.1146, 0.0702,
#          0.0477],
#         [0.0761, 0.1438, 0.1104, 0.1135, 0.1494, 0.0750, 0.0600, 0.0869, 0.0875,
#          0.0974],
#         [0.0909, 0.1858, 0.1560, 0.0721, 0.1010, 0.1146, 0.0771, 0.0827, 0.0605,
#          0.0592],
#         [0.0886, 0.1368, 0.1048, 0.0879, 0.1823, 0.1127, 0.0906, 0.0631, 0.0497,
#          0.0836],
#         [0.0640, 0.1532, 0.1597, 0.1094, 0.1571, 0.0777, 0.0559, 0.0973, 0.0826,
#          0.0431],
#         [0.0640, 0.1105, 0.1334, 0.1125, 0.2428, 0.0979, 0.0650, 0.0860, 0.0525,
#          0.0352],
#         [0.1017, 0.1383, 0.1204, 0.0935, 0.2228, 0.0787, 0.0580, 0.0937, 0.0530,
#          0.0400],
#         [0.0668, 0.1687, 0.1049, 0.1346, 0.2299, 0.0782, 0.0408, 0.0709, 0.0579,
#          0.0473],
#         [0.0856, 0.1330, 0.1693, 0.0844, 0.1392, 0.0828, 0.0799, 0.0959, 0.0628,
#          0.0670],
#         [0.0878, 0.1168, 0.1180, 0.0921, 0.2143, 0.0922, 0.0694, 0.1250, 0.0435,
#          0.0409],
#         [0.0964, 0.1486, 0.1259, 0.0810, 0.1986, 0.0758, 0.0701, 0.1068, 0.0538,
#          0.0429],
#         [0.0868, 0.1197, 0.1230, 0.0913, 0.1594, 0.1108, 0.0752, 0.0754, 0.0691,
#          0.0894]], device='cuda:0', grad_fn=<SoftmaxBackward>)
# tensor([[0.0902, 0.1675, 0.1265, 0.0780, 0.1934, 0.0653, 0.0597, 0.0968, 0.0614,
#          0.0613],
#         [0.0726, 0.1245, 0.0932, 0.0859, 0.2103, 0.1405, 0.0516, 0.0893, 0.0765,
#          0.0557],
#         [0.0853, 0.1301, 0.1378, 0.0714, 0.1709, 0.0655, 0.0583, 0.1246, 0.0667,
#          0.0892],
#         [0.0994, 0.1316, 0.1000, 0.0953, 0.2253, 0.0610, 0.0528, 0.1272, 0.0520,
#          0.0554],
#         [0.0815, 0.1850, 0.0885, 0.0760, 0.1311, 0.1014, 0.0773, 0.0893, 0.0798,
#          0.0901],
#         [0.0788, 0.1547, 0.1029, 0.0837, 0.1685, 0.1229, 0.0644, 0.0855, 0.0643,
#          0.0744],
#         [0.0697, 0.1408, 0.0972, 0.0751, 0.2626, 0.0843, 0.0675, 0.0870, 0.0631,
#          0.0527],
#         [0.0594, 0.1701, 0.1640, 0.0912, 0.1287, 0.0804, 0.0586, 0.1093, 0.0625,
#          0.0757],
#         [0.0780, 0.1439, 0.1478, 0.0840, 0.1739, 0.0593, 0.0666, 0.0980, 0.0715,
#          0.0771],
#         [0.0717, 0.1589, 0.0905, 0.0955, 0.1930, 0.0738, 0.0515, 0.1338, 0.0754,
#          0.0558],
#         [0.0845, 0.1567, 0.1680, 0.0906, 0.1205, 0.1064, 0.0721, 0.0828, 0.0406,
#          0.0778],
#         [0.0752, 0.1333, 0.1327, 0.0898, 0.1581, 0.0814, 0.0749, 0.1350, 0.0625,
#          0.0571],
#         [0.0969, 0.1501, 0.1458, 0.0796, 0.1575, 0.0582, 0.0466, 0.1370, 0.0659,
#          0.0624],
#         [0.0796, 0.1422, 0.1629, 0.0660, 0.1551, 0.0719, 0.0818, 0.0842, 0.0784,
#          0.0779],
#         [0.0781, 0.1062, 0.1863, 0.1111, 0.1578, 0.1190, 0.0400, 0.0874, 0.0655,
#          0.0486],
#         [0.1192, 0.1175, 0.1599, 0.0683, 0.1528, 0.0894, 0.0891, 0.0918, 0.0597,
#          0.0522]], device='cuda:0', grad_fn=<SoftmaxBackward>)
# tensor([[0.0627, 0.1799, 0.0955, 0.0714, 0.2034, 0.0721, 0.0470, 0.1173, 0.0961,
#          0.0546],
#         [0.0929, 0.1549, 0.1146, 0.0763, 0.2084, 0.0917, 0.0514, 0.0969, 0.0603,
#          0.0525],
#         [0.0877, 0.1612, 0.0839, 0.0695, 0.1672, 0.0785, 0.0918, 0.1009, 0.0812,
#          0.0782],
#         [0.0488, 0.1483, 0.1091, 0.1011, 0.2025, 0.0693, 0.0660, 0.1132, 0.0706,
#          0.0709],
#         [0.0749, 0.1057, 0.1743, 0.1031, 0.2296, 0.0866, 0.0412, 0.0777, 0.0522,
#          0.0547],
#         [0.0979, 0.1307, 0.1523, 0.1269, 0.1543, 0.0907, 0.0437, 0.0863, 0.0569,
#          0.0603],
#         [0.0835, 0.1811, 0.1659, 0.0928, 0.1416, 0.0720, 0.0729, 0.0980, 0.0383,
#          0.0537],
#         [0.0714, 0.1562, 0.1034, 0.0907, 0.1118, 0.0987, 0.0757, 0.1322, 0.0706,
#          0.0893],
#         [0.0932, 0.1323, 0.1221, 0.0957, 0.1911, 0.1047, 0.0487, 0.0962, 0.0463,
#          0.0696],
#         [0.0832, 0.1535, 0.1453, 0.0761, 0.1446, 0.1179, 0.0723, 0.0902, 0.0541,
#          0.0628],
#         [0.0686, 0.1280, 0.1598, 0.1105, 0.1446, 0.1000, 0.0639, 0.0750, 0.0736,
#          0.0760],
#         [0.0646, 0.1555, 0.1109, 0.1190, 0.1603, 0.0770, 0.0648, 0.0951, 0.0662,
#          0.0866],
#         [0.1039, 0.1301, 0.1413, 0.1012, 0.1297, 0.0824, 0.0647, 0.0860, 0.0914,
#          0.0693],
#         [0.0691, 0.1419, 0.1214, 0.0749, 0.2130, 0.0721, 0.0758, 0.1097, 0.0676,
#          0.0545],
#         [0.0937, 0.1223, 0.1333, 0.0916, 0.1840, 0.1135, 0.0574, 0.0920, 0.0483,
#          0.0639],
#         [0.0836, 0.1514, 0.1727, 0.0780, 0.1275, 0.0805, 0.0858, 0.0653, 0.0844,
#          0.0708]], device='cuda:0', grad_fn=<SoftmaxBackward>)

# %%
total_params = sum(p.numel() for p in model.parameters())
print("Num of Total Parameter : ",total_params)
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print("Num of Trainable Parameter :",trainable_params)
# Out:
# Num of Total Parameter :  153350
# Num of Trainable Parameter : 153350

# %% [markdown]
# ## Train

# %% [markdown]
# ### Holdout

# %%
EPOCHS = range(200)

verbose = 3

trn_losses, val_losses = [], []
trn_accs, val_accs = [], []

for epoch in EPOCHS:

    trn_bth_loss, trn_bth_acc = 0, 0
    trn_cnt = 0
    model.train()
    for x, y in trn_dl:
        
        x, y = x.to(device), y.to(device)

        optimizer.zero_grad()

        y_pred = model(x).to(device)

        loss = loss_fn(y_pred, y)
        loss.backward()
        optimizer.step()

        trn_bth_loss += loss.item()
        acc, cnt = accuracy(y_pred, y)
        trn_bth_acc += acc
        trn_cnt += cnt

    trn_losses.append(trn_bth_loss)
    trn_accs.append(trn_bth_acc / trn_cnt * 100)


    val_bth_loss, val_bth_acc = 0, 0
    val_cnt = 0
    model.eval()
    with torch.no_grad():
        for x, y in tst_dl:
            
            x, y = x.to(device), y.to(device)

            y_pred = model(x).to(device)

            loss = loss_fn(y_pred, y)

            val_bth_loss += loss.item()
            acc, cnt = accuracy(y_pred, y)
            val_bth_acc += acc
            val_cnt += cnt

        val_losses.append(val_bth_loss)
        val_accs.append(val_bth_acc / val_cnt * 100)

    if verbose == 0:
        if epoch % 5 == 0:
            print(f'EPOCHS {epoch} :: [LOSS] {val_losses[-1]:.3f} | [ACC] {val_accs[-1]:.3f}%')

    elif verbose == 1:
        print(f'EPOCHS {epoch} :: [LOSS] {val_losses[-1]:.3f} | [ACC] {val_accs[-1]:.3f}%')

    elif verbose == 2:
        print(f'EPOCHS {epoch}')
        print(f'TRAIN :: [LOSS] {trn_losses[-1]:.3f} | [ACC] {trn_accs[-1]:.3f}%')
        print(f'VALID :: [LOSS] {val_losses[-1]:.3f} | [ACC] {val_accs[-1]:.3f}%\n')

    elif verbose == 3:
        print(f'EPOCHS {epoch}')
        print(f'TRAIN :: [LOSS] {trn_losses[-1]:.3f} | [ACC] {trn_accs[-1]:.3f}%, {trn_bth_acc}/{trn_cnt}')
        print(f'VALID :: [LOSS] {val_losses[-1]:.3f} | [ACC] {val_accs[-1]:.3f}%, {val_bth_acc}/{val_cnt}\n')
# Out:
# EPOCHS 0
# TRAIN :: [LOSS] 103.810 | [ACC] 9.812%, 68/693
# VALID :: [LOSS] 26.104 | [ACC] 9.195%, 16/174
#
# EPOCHS 1
# TRAIN :: [LOSS] 103.828 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.087 | [ACC] 9.195%, 16/174
#
# EPOCHS 2
# TRAIN :: [LOSS] 103.845 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.087 | [ACC] 9.195%, 16/174
#
# EPOCHS 3
# TRAIN :: [LOSS] 103.859 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.091 | [ACC] 9.195%, 16/174
#
# EPOCHS 4
# TRAIN :: [LOSS] 103.852 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.099 | [ACC] 9.195%, 16/174
#
# EPOCHS 5
# TRAIN :: [LOSS] 103.737 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.074 | [ACC] 9.195%, 16/174
#
# EPOCHS 6
# TRAIN :: [LOSS] 103.855 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.077 | [ACC] 9.195%, 16/174
#
# EPOCHS 7
# TRAIN :: [LOSS] 103.814 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.079 | [ACC] 9.195%, 16/174
#
# EPOCHS 8
# TRAIN :: [LOSS] 103.845 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.090 | [ACC] 9.195%, 16/174
#
# EPOCHS 9
# TRAIN :: [LOSS] 103.850 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.070 | [ACC] 9.195%, 16/174
#
# EPOCHS 10
# TRAIN :: [LOSS] 103.845 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.095 | [ACC] 9.195%, 16/174
#
# EPOCHS 11
# TRAIN :: [LOSS] 103.565 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.087 | [ACC] 9.195%, 16/174
#
# EPOCHS 12
# TRAIN :: [LOSS] 103.830 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.097 | [ACC] 9.195%, 16/174
#
# EPOCHS 13
# TRAIN :: [LOSS] 103.859 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.078 | [ACC] 9.195%, 16/174
#
# EPOCHS 14
# TRAIN :: [LOSS] 103.690 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.082 | [ACC] 9.195%, 16/174
#
# EPOCHS 15
# TRAIN :: [LOSS] 103.830 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.075 | [ACC] 9.195%, 16/174
#
# EPOCHS 16
# TRAIN :: [LOSS] 103.839 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.088 | [ACC] 9.195%, 16/174
#
# EPOCHS 17
# TRAIN :: [LOSS] 103.861 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.073 | [ACC] 9.195%, 16/174
#
# EPOCHS 18
# TRAIN :: [LOSS] 103.588 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.093 | [ACC] 9.195%, 16/174
#
# EPOCHS 19
# TRAIN :: [LOSS] 103.850 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.067 | [ACC] 9.195%, 16/174
#
# EPOCHS 20
# TRAIN :: [LOSS] 103.690 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.068 | [ACC] 9.195%, 16/174
#
# EPOCHS 21
# TRAIN :: [LOSS] 103.847 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.080 | [ACC] 9.195%, 16/174
#
# EPOCHS 22
# TRAIN :: [LOSS] 103.862 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.078 | [ACC] 9.195%, 16/174
#
# EPOCHS 23
# TRAIN :: [LOSS] 103.819 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.062 | [ACC] 9.195%, 16/174
#
# EPOCHS 24
# TRAIN :: [LOSS] 103.849 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.090 | [ACC] 9.195%, 16/174
#
# EPOCHS 25
# TRAIN :: [LOSS] 103.838 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.069 | [ACC] 9.195%, 16/174
#
# EPOCHS 26
# TRAIN :: [LOSS] 103.591 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.093 | [ACC] 9.195%, 16/174
#
# EPOCHS 27
# TRAIN :: [LOSS] 103.567 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.087 | [ACC] 9.195%, 16/174
#
# EPOCHS 28
# TRAIN :: [LOSS] 103.708 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.091 | [ACC] 9.195%, 16/174
#
# EPOCHS 29
# TRAIN :: [LOSS] 103.862 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.085 | [ACC] 9.195%, 16/174
#
# EPOCHS 30
# TRAIN :: [LOSS] 103.867 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.072 | [ACC] 9.195%, 16/174
#
# EPOCHS 31
# TRAIN :: [LOSS] 103.847 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.071 | [ACC] 9.195%, 16/174
#
# EPOCHS 32
# TRAIN :: [LOSS] 103.709 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.079 | [ACC] 9.195%, 16/174
#
# EPOCHS 33
# TRAIN :: [LOSS] 103.571 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.085 | [ACC] 9.195%, 16/174
#
# EPOCHS 34
# TRAIN :: [LOSS] 103.709 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.076 | [ACC] 9.195%, 16/174
#
# EPOCHS 35
# TRAIN :: [LOSS] 103.723 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.090 | [ACC] 9.195%, 16/174
#
# EPOCHS 36
# TRAIN :: [LOSS] 103.840 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.086 | [ACC] 9.195%, 16/174
#
# EPOCHS 37
# TRAIN :: [LOSS] 103.725 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.061 | [ACC] 9.195%, 16/174
#
# EPOCHS 38
# TRAIN :: [LOSS] 103.852 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.094 | [ACC] 9.195%, 16/174
#
# EPOCHS 39
# TRAIN :: [LOSS] 103.670 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.080 | [ACC] 9.195%, 16/174
#
# EPOCHS 40
# TRAIN :: [LOSS] 103.839 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.083 | [ACC] 9.195%, 16/174
#
# EPOCHS 41
# TRAIN :: [LOSS] 103.722 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.068 | [ACC] 9.195%, 16/174
#
# EPOCHS 42
# TRAIN :: [LOSS] 103.832 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.078 | [ACC] 9.195%, 16/174
#
# EPOCHS 43
# TRAIN :: [LOSS] 103.864 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.081 | [ACC] 9.195%, 16/174
#
# EPOCHS 44
# TRAIN :: [LOSS] 103.857 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.076 | [ACC] 9.195%, 16/174
#
# EPOCHS 45
# TRAIN :: [LOSS] 103.833 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.084 | [ACC] 9.195%, 16/174
#
# EPOCHS 46
# TRAIN :: [LOSS] 103.838 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.088 | [ACC] 9.195%, 16/174
#
# EPOCHS 47
# TRAIN :: [LOSS] 103.714 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.053 | [ACC] 9.195%, 16/174
#
# EPOCHS 48
# TRAIN :: [LOSS] 103.695 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.086 | [ACC] 9.195%, 16/174
#
# EPOCHS 49
# TRAIN :: [LOSS] 103.589 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.067 | [ACC] 9.195%, 16/174
#
# EPOCHS 50
# TRAIN :: [LOSS] 103.839 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.059 | [ACC] 9.195%, 16/174
#
# EPOCHS 51
# TRAIN :: [LOSS] 103.836 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.097 | [ACC] 9.195%, 16/174
#
# EPOCHS 52
# TRAIN :: [LOSS] 103.845 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.059 | [ACC] 9.195%, 16/174
#
# EPOCHS 53
# TRAIN :: [LOSS] 103.689 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.075 | [ACC] 9.195%, 16/174
#
# EPOCHS 54
# TRAIN :: [LOSS] 103.692 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.084 | [ACC] 9.195%, 16/174
#
# EPOCHS 55
# TRAIN :: [LOSS] 103.844 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.081 | [ACC] 9.195%, 16/174
#
# EPOCHS 56
# TRAIN :: [LOSS] 103.790 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.088 | [ACC] 9.195%, 16/174
#
# EPOCHS 57
# TRAIN :: [LOSS] 103.560 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.073 | [ACC] 9.195%, 16/174
#
# EPOCHS 58
# TRAIN :: [LOSS] 103.848 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.066 | [ACC] 9.195%, 16/174
#
# EPOCHS 59
# TRAIN :: [LOSS] 103.694 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.062 | [ACC] 9.195%, 16/174
#
# EPOCHS 60
# TRAIN :: [LOSS] 103.848 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.083 | [ACC] 9.195%, 16/174
#
# EPOCHS 61
# TRAIN :: [LOSS] 103.567 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.073 | [ACC] 9.195%, 16/174
#
# EPOCHS 62
# TRAIN :: [LOSS] 103.711 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.100 | [ACC] 9.195%, 16/174
#
# EPOCHS 63
# TRAIN :: [LOSS] 103.872 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.094 | [ACC] 9.195%, 16/174
#
# EPOCHS 64
# TRAIN :: [LOSS] 103.697 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.091 | [ACC] 9.195%, 16/174
#
# EPOCHS 65
# TRAIN :: [LOSS] 103.855 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.077 | [ACC] 9.195%, 16/174
#
# EPOCHS 66
# TRAIN :: [LOSS] 103.728 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.096 | [ACC] 9.195%, 16/174
#
# EPOCHS 67
# TRAIN :: [LOSS] 103.707 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.071 | [ACC] 9.195%, 16/174
#
# EPOCHS 68
# TRAIN :: [LOSS] 103.721 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.078 | [ACC] 9.195%, 16/174
#
# EPOCHS 69
# TRAIN :: [LOSS] 103.857 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.080 | [ACC] 9.195%, 16/174
#
# EPOCHS 70
# TRAIN :: [LOSS] 103.836 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.083 | [ACC] 9.195%, 16/174
#
# EPOCHS 71
# TRAIN :: [LOSS] 103.850 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.094 | [ACC] 9.195%, 16/174
#
# EPOCHS 72
# TRAIN :: [LOSS] 103.698 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.065 | [ACC] 9.195%, 16/174
#
# EPOCHS 73
# TRAIN :: [LOSS] 103.849 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.070 | [ACC] 9.195%, 16/174
#
# EPOCHS 74
# TRAIN :: [LOSS] 103.736 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.082 | [ACC] 9.195%, 16/174
#
# EPOCHS 75
# TRAIN :: [LOSS] 103.710 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.068 | [ACC] 9.195%, 16/174
#
# EPOCHS 76
# TRAIN :: [LOSS] 103.701 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.077 | [ACC] 9.195%, 16/174
#
# EPOCHS 77
# TRAIN :: [LOSS] 103.842 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.081 | [ACC] 9.195%, 16/174
#
# EPOCHS 78
# TRAIN :: [LOSS] 103.719 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.093 | [ACC] 9.195%, 16/174
# EPOCHS 79
# TRAIN :: [LOSS] 103.682 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.074 | [ACC] 9.195%, 16/174
#
# EPOCHS 80
# TRAIN :: [LOSS] 103.561 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.086 | [ACC] 9.195%, 16/174
#
# EPOCHS 81
# TRAIN :: [LOSS] 103.704 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.076 | [ACC] 9.195%, 16/174
#
# EPOCHS 82
# TRAIN :: [LOSS] 103.841 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.086 | [ACC] 9.195%, 16/174
#
# EPOCHS 83
# TRAIN :: [LOSS] 103.852 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.071 | [ACC] 9.195%, 16/174
#
# EPOCHS 84
# TRAIN :: [LOSS] 103.837 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.090 | [ACC] 9.195%, 16/174
#
# EPOCHS 85
# TRAIN :: [LOSS] 103.848 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.091 | [ACC] 9.195%, 16/174
#
# EPOCHS 86
# TRAIN :: [LOSS] 103.703 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.079 | [ACC] 9.195%, 16/174
#
# EPOCHS 87
# TRAIN :: [LOSS] 103.852 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.084 | [ACC] 9.195%, 16/174
#
# EPOCHS 88
# TRAIN :: [LOSS] 103.857 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.070 | [ACC] 9.195%, 16/174
#
# EPOCHS 89
# TRAIN :: [LOSS] 103.675 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.059 | [ACC] 9.195%, 16/174
#
# EPOCHS 90
# TRAIN :: [LOSS] 103.839 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.085 | [ACC] 9.195%, 16/174
#
# EPOCHS 91
# TRAIN :: [LOSS] 103.827 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.104 | [ACC] 9.195%, 16/174
#
# EPOCHS 92
# TRAIN :: [LOSS] 103.576 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.082 | [ACC] 9.195%, 16/174
#
# EPOCHS 93
# TRAIN :: [LOSS] 103.863 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.093 | [ACC] 9.195%, 16/174
#
# EPOCHS 94
# TRAIN :: [LOSS] 103.695 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.076 | [ACC] 9.195%, 16/174
#
# EPOCHS 95
# TRAIN :: [LOSS] 103.840 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.072 | [ACC] 9.195%, 16/174
#
# EPOCHS 96
# TRAIN :: [LOSS] 103.822 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.076 | [ACC] 9.195%, 16/174
#
# EPOCHS 97
# TRAIN :: [LOSS] 103.715 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.088 | [ACC] 9.195%, 16/174
#
# EPOCHS 98
# TRAIN :: [LOSS] 103.726 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.085 | [ACC] 9.195%, 16/174
#
# EPOCHS 99
# TRAIN :: [LOSS] 103.838 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.075 | [ACC] 9.195%, 16/174
#
# EPOCHS 100
# TRAIN :: [LOSS] 103.855 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.063 | [ACC] 9.195%, 16/174
#
# EPOCHS 101
# TRAIN :: [LOSS] 103.858 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.066 | [ACC] 9.195%, 16/174
#
# EPOCHS 102
# TRAIN :: [LOSS] 103.836 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.075 | [ACC] 9.195%, 16/174
#
# EPOCHS 103
# TRAIN :: [LOSS] 103.842 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.086 | [ACC] 9.195%, 16/174
#
# EPOCHS 104
# TRAIN :: [LOSS] 103.710 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.058 | [ACC] 9.195%, 16/174
#
# EPOCHS 105
# TRAIN :: [LOSS] 103.821 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.092 | [ACC] 9.195%, 16/174
#
# EPOCHS 106
# TRAIN :: [LOSS] 103.593 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.094 | [ACC] 9.195%, 16/174
#
# EPOCHS 107
# TRAIN :: [LOSS] 103.837 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.076 | [ACC] 9.195%, 16/174
#
# EPOCHS 108
# TRAIN :: [LOSS] 103.681 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.079 | [ACC] 9.195%, 16/174
#
# EPOCHS 109
# TRAIN :: [LOSS] 103.830 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.091 | [ACC] 9.195%, 16/174
#
# EPOCHS 110
# TRAIN :: [LOSS] 103.679 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.080 | [ACC] 9.195%, 16/174
#
# EPOCHS 111
# TRAIN :: [LOSS] 103.841 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.067 | [ACC] 9.195%, 16/174
#
# EPOCHS 112
# TRAIN :: [LOSS] 103.734 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.072 | [ACC] 9.195%, 16/174
#
# EPOCHS 113
# TRAIN :: [LOSS] 103.697 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.088 | [ACC] 9.195%, 16/174
#
# EPOCHS 114
# TRAIN :: [LOSS] 103.550 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.087 | [ACC] 9.195%, 16/174
#
# EPOCHS 115
# TRAIN :: [LOSS] 103.718 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.090 | [ACC] 9.195%, 16/174
#
# EPOCHS 116
# TRAIN :: [LOSS] 103.882 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.087 | [ACC] 9.195%, 16/174
#
# EPOCHS 117
# TRAIN :: [LOSS] 103.848 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.044 | [ACC] 9.195%, 16/174
#
# EPOCHS 118
# TRAIN :: [LOSS] 103.698 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.085 | [ACC] 9.195%, 16/174
#
# EPOCHS 119
# TRAIN :: [LOSS] 103.851 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.078 | [ACC] 9.195%, 16/174
#
# EPOCHS 120
# TRAIN :: [LOSS] 103.691 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.070 | [ACC] 9.195%, 16/174
#
# EPOCHS 121
# TRAIN :: [LOSS] 103.830 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.085 | [ACC] 9.195%, 16/174
#
# EPOCHS 122
# TRAIN :: [LOSS] 103.724 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.058 | [ACC] 9.195%, 16/174
#
# EPOCHS 123
# TRAIN :: [LOSS] 103.843 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.081 | [ACC] 9.195%, 16/174
#
# EPOCHS 124
# TRAIN :: [LOSS] 103.717 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.065 | [ACC] 9.195%, 16/174
#
# EPOCHS 125
# TRAIN :: [LOSS] 103.575 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.057 | [ACC] 9.195%, 16/174
#
# EPOCHS 126
# TRAIN :: [LOSS] 103.716 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.074 | [ACC] 9.195%, 16/174
#
# EPOCHS 127
# TRAIN :: [LOSS] 103.706 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.051 | [ACC] 9.195%, 16/174
#
# EPOCHS 128
# TRAIN :: [LOSS] 103.838 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.069 | [ACC] 9.195%, 16/174
#
# EPOCHS 129
# TRAIN :: [LOSS] 103.716 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.080 | [ACC] 9.195%, 16/174
#
# EPOCHS 130
# TRAIN :: [LOSS] 103.723 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.095 | [ACC] 9.195%, 16/174
#
# EPOCHS 131
# TRAIN :: [LOSS] 103.858 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.052 | [ACC] 9.195%, 16/174
#
# EPOCHS 132
# TRAIN :: [LOSS] 103.873 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.079 | [ACC] 9.195%, 16/174
#
# EPOCHS 133
# TRAIN :: [LOSS] 103.688 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.091 | [ACC] 9.195%, 16/174
#
# EPOCHS 134
# TRAIN :: [LOSS] 103.857 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.086 | [ACC] 9.195%, 16/174
#
# EPOCHS 135
# TRAIN :: [LOSS] 103.827 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.076 | [ACC] 9.195%, 16/174
#
# EPOCHS 136
# TRAIN :: [LOSS] 103.825 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.092 | [ACC] 9.195%, 16/174
#
# EPOCHS 137
# TRAIN :: [LOSS] 103.824 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.077 | [ACC] 9.195%, 16/174
#
# EPOCHS 138
# TRAIN :: [LOSS] 103.832 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.078 | [ACC] 9.195%, 16/174
#
# EPOCHS 139
# TRAIN :: [LOSS] 103.548 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.074 | [ACC] 9.195%, 16/174
#
# EPOCHS 140
# TRAIN :: [LOSS] 103.694 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.086 | [ACC] 9.195%, 16/174
#
# EPOCHS 141
# TRAIN :: [LOSS] 103.880 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.076 | [ACC] 9.195%, 16/174
#
# EPOCHS 142
# TRAIN :: [LOSS] 103.857 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.078 | [ACC] 9.195%, 16/174
#
# EPOCHS 143
# TRAIN :: [LOSS] 103.855 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.077 | [ACC] 9.195%, 16/174
#
# EPOCHS 144
# TRAIN :: [LOSS] 103.842 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.078 | [ACC] 9.195%, 16/174
#
# EPOCHS 145
# TRAIN :: [LOSS] 103.574 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.070 | [ACC] 9.195%, 16/174
#
# EPOCHS 146
# TRAIN :: [LOSS] 103.708 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.092 | [ACC] 9.195%, 16/174
#
# EPOCHS 147
# TRAIN :: [LOSS] 103.686 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.080 | [ACC] 9.195%, 16/174
#
# EPOCHS 148
# TRAIN :: [LOSS] 103.846 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.087 | [ACC] 9.195%, 16/174
#
# EPOCHS 149
# TRAIN :: [LOSS] 103.692 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.097 | [ACC] 9.195%, 16/174
#
# EPOCHS 150
# TRAIN :: [LOSS] 103.720 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.088 | [ACC] 9.195%, 16/174
#
# EPOCHS 151
# TRAIN :: [LOSS] 103.831 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.062 | [ACC] 9.195%, 16/174
#
# EPOCHS 152
# TRAIN :: [LOSS] 103.836 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.076 | [ACC] 9.195%, 16/174
#
# EPOCHS 153
# TRAIN :: [LOSS] 103.831 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.087 | [ACC] 9.195%, 16/174
#
# EPOCHS 154
# TRAIN :: [LOSS] 103.690 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.060 | [ACC] 9.195%, 16/174
#
# EPOCHS 155
# TRAIN :: [LOSS] 103.848 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.081 | [ACC] 9.195%, 16/174
#
# EPOCHS 156
# TRAIN :: [LOSS] 103.729 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.096 | [ACC] 9.195%, 16/174
# EPOCHS 157
# TRAIN :: [LOSS] 103.845 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.057 | [ACC] 9.195%, 16/174
#
# EPOCHS 158
# TRAIN :: [LOSS] 103.853 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.086 | [ACC] 9.195%, 16/174
#
# EPOCHS 159
# TRAIN :: [LOSS] 103.701 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.077 | [ACC] 9.195%, 16/174
#
# EPOCHS 160
# TRAIN :: [LOSS] 103.818 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.087 | [ACC] 9.195%, 16/174
#
# EPOCHS 161
# TRAIN :: [LOSS] 103.816 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.094 | [ACC] 9.195%, 16/174
#
# EPOCHS 162
# TRAIN :: [LOSS] 103.861 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.060 | [ACC] 9.195%, 16/174
#
# EPOCHS 163
# TRAIN :: [LOSS] 103.833 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.086 | [ACC] 9.195%, 16/174
#
# EPOCHS 164
# TRAIN :: [LOSS] 103.850 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.062 | [ACC] 9.195%, 16/174
#
# EPOCHS 165
# TRAIN :: [LOSS] 103.711 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.074 | [ACC] 9.195%, 16/174
#
# EPOCHS 166
# TRAIN :: [LOSS] 103.694 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.097 | [ACC] 9.195%, 16/174
#
# EPOCHS 167
# TRAIN :: [LOSS] 103.816 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.080 | [ACC] 9.195%, 16/174
#
# EPOCHS 168
# TRAIN :: [LOSS] 103.549 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.091 | [ACC] 9.195%, 16/174
#
# EPOCHS 169
# TRAIN :: [LOSS] 103.731 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.099 | [ACC] 9.195%, 16/174
#
# EPOCHS 170
# TRAIN :: [LOSS] 103.708 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.081 | [ACC] 9.195%, 16/174
#
# EPOCHS 171
# TRAIN :: [LOSS] 103.853 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.073 | [ACC] 9.195%, 16/174
#
# EPOCHS 172
# TRAIN :: [LOSS] 103.843 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.091 | [ACC] 9.195%, 16/174
#
# EPOCHS 173
# TRAIN :: [LOSS] 103.748 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.086 | [ACC] 9.195%, 16/174
#
# EPOCHS 174
# TRAIN :: [LOSS] 103.844 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.078 | [ACC] 9.195%, 16/174
#
# EPOCHS 175
# TRAIN :: [LOSS] 103.832 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.084 | [ACC] 9.195%, 16/174
#
# EPOCHS 176
# TRAIN :: [LOSS] 103.695 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.087 | [ACC] 9.195%, 16/174
#
# EPOCHS 177
# TRAIN :: [LOSS] 103.728 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.066 | [ACC] 9.195%, 16/174
#
# EPOCHS 178
# TRAIN :: [LOSS] 103.835 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.091 | [ACC] 9.195%, 16/174
#
# EPOCHS 179
# TRAIN :: [LOSS] 103.834 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.078 | [ACC] 9.195%, 16/174
#
# EPOCHS 180
# TRAIN :: [LOSS] 103.727 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.080 | [ACC] 9.195%, 16/174
#
# EPOCHS 181
# TRAIN :: [LOSS] 103.712 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.070 | [ACC] 9.195%, 16/174
#
# EPOCHS 182
# TRAIN :: [LOSS] 103.850 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.084 | [ACC] 9.195%, 16/174
#
# EPOCHS 183
# TRAIN :: [LOSS] 103.849 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.080 | [ACC] 9.195%, 16/174
#
# EPOCHS 184
# TRAIN :: [LOSS] 103.726 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.087 | [ACC] 9.195%, 16/174
#
# EPOCHS 185
# TRAIN :: [LOSS] 103.725 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.079 | [ACC] 9.195%, 16/174
#
# EPOCHS 186
# TRAIN :: [LOSS] 103.710 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.075 | [ACC] 9.195%, 16/174
#
# EPOCHS 187
# TRAIN :: [LOSS] 103.843 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.077 | [ACC] 9.195%, 16/174
#
# EPOCHS 188
# TRAIN :: [LOSS] 103.821 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.066 | [ACC] 9.195%, 16/174
#
# EPOCHS 189
# TRAIN :: [LOSS] 103.703 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.065 | [ACC] 9.195%, 16/174
#
# EPOCHS 190
# TRAIN :: [LOSS] 103.695 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.078 | [ACC] 9.195%, 16/174
#
# EPOCHS 191
# TRAIN :: [LOSS] 103.871 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.092 | [ACC] 9.195%, 16/174
#
# EPOCHS 192
# TRAIN :: [LOSS] 103.851 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.093 | [ACC] 9.195%, 16/174
#
# EPOCHS 193
# TRAIN :: [LOSS] 103.836 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.076 | [ACC] 9.195%, 16/174
#
# EPOCHS 194
# TRAIN :: [LOSS] 103.856 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.057 | [ACC] 9.195%, 16/174
#
# EPOCHS 195
# TRAIN :: [LOSS] 103.842 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.077 | [ACC] 9.195%, 16/174
#
# EPOCHS 196
# TRAIN :: [LOSS] 103.841 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.059 | [ACC] 9.195%, 16/174
#
# EPOCHS 197
# TRAIN :: [LOSS] 103.864 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.090 | [ACC] 9.195%, 16/174
#
# EPOCHS 198
# TRAIN :: [LOSS] 103.853 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.085 | [ACC] 9.195%, 16/174
#
# EPOCHS 199
# TRAIN :: [LOSS] 103.829 | [ACC] 10.390%, 72/693
# VALID :: [LOSS] 26.090 | [ACC] 9.195%, 16/174

# %%
comments = f'BATCH: {BATCH} | LR: {LEARNING_RATE} | EPOCHS: {EPOCHS}'
save_model(model, EPOCHS, optimizer, loss_fn, [trn_losses, val_losses, trn_accs, val_accs], comments)

# %% [markdown]
# ### K-Folds

# %%
EPOCHS = range(200)
FOLDS = 10

SPLITS = 10

cv_loss_trn, cv_loss_val = [], []
cv_accs_trn, cv_accs_val = [], []

verbose = 3

kfold = KFold(n_splits=SPLITS)
for i, (trn_idx, val_idx) in enumerate(kfold.split(X_train)):
    print(f'FOLD :: {i}')
    
    trn_fdl = DataLoader(TensorDataset(X_train[trn_idx], y_train[trn_idx]))
    val_fdl = DataLoader(TensorDataset(X_train[val_idx], y_train[val_idx]))
    
    trn_losses, val_losses = [], []
    trn_accs, val_accs = [], []
    
    for epoch in EPOCHS:
        
        trn_bth_loss, trn_bth_acc = 0, 0
        trn_cnt = 0
        model.train()
        for x, y in trn_fdl:
            
            optimizer.zero_grad()
            
            y_pred = model(x)
            
            loss = loss_fn(y_pred, y)
            loss.backward()
            optimizer.step()
            
            trn_bth_loss += loss.item()
            acc, cnt = accuracy(y_pred, y)
            trn_bth_acc += acc
            trn_cnt += cnt
            
        #trn_cnt = trn_fdl.__len__()
        trn_losses.append(trn_bth_loss / trn_cnt)
        trn_accs.append(trn_bth_acc / trn_cnt * 100)
        
        
        val_bth_loss, val_bth_acc = 0, 0
        val_cnt = 0
        model.eval()
        with torch.no_grad():
            for x, y in val_fdl:

                y_pred = model(x)

                loss = loss_fn(y_pred, y)

                val_bth_loss += loss.item()
                acc, cnt = accuracy(y_pred, y)
                val_bth_acc += acc
                val_cnt += cnt

            #val_cnt = val_fdl.__len__()
            val_losses.append(val_bth_loss / val_cnt)
            val_accs.append(val_bth_acc / val_cnt * 100)
        
        if verbose == 0:
            if epoch % 5 == 0:
                print(f'EPOCHS {epoch} :: [LOSS] {val_losses[-1]:.3f} | [ACC] {val_accs[-1]:.3f}%')
                
        elif verbose == 1:
            print(f'EPOCHS {epoch} :: [LOSS] {val_losses[-1]:.3f} | [ACC] {val_accs[-1]:.3f}%')
            
        elif verbose == 2:
            print(f'EPOCHS {epoch}')
            print(f'TRAIN :: [LOSS] {trn_losses[-1]:.3f} | [ACC] {trn_accs[-1]:.3f}%')
            print(f'VALID :: [LOSS] {val_losses[-1]:.3f} | [ACC] {val_accs[-1]:.3f}%\n')
            
        elif verbose == 3:
            print(f'EPOCHS {epoch}')
            print(f'TRAIN :: [LOSS] {trn_losses[-1]:.3f} | [ACC] {trn_accs[-1]:.3f}%, {trn_bth_acc}/{trn_cnt}')
            print(f'VALID :: [LOSS] {val_losses[-1]:.3f} | [ACC] {val_accs[-1]:.3f}%, {val_bth_acc}/{val_cnt}\n')
            
    cv_loss_trn.append(trn_losses)
    cv_accs_trn.append(trn_accs)
    
    cv_loss_val.append(val_losses)
    cv_accs_val.append(val_accs)
# Out:
# FOLD :: 0

# %%
from utils.plotting_utils import *

cv_plotter(cv_loss_trn, cv_loss_val, title='loss')

# %%
cv_plotter(cv_accs_trn, cv_accs_val, title='acc')

# %% [markdown]
# ## With Hold-out Testset

# %%
with torch.no_grad():
    
    tst_loss, tst_acc = 0, 0
    tst_cnt = 0
    model.eval()
    for x, y in tst_dl:
        
        y_pred = model(x)
        
        loss = loss_fn(y_pred, y)
        
        tst_loss += loss.item()
        acc, cnt = accuracy(y_pred, y)
        tst_acc += acc
        tst_cnt += cnt
    
    #tst_acc /= tst_cnt
print(f'HOLDOUT TESTSET :: [LOSS] {tst_loss:.3f} | [ACC] {tst_acc/tst_cnt * 100:.3f}% {tst_acc}/{tst_cnt}')

# %%
y_pred.argmax(axis=1), y

# %% [markdown]
# ## Save Model

# %%
import time
t = time.gmtime(time.time())

SAVE_PATH = f'./models/{t.tm_year}_{t.tm_mon}_{t.tm_mday}-{t.tm_hour}_{t.tm_min}.pt'
torch.save({
            'epoch': EPOCHS,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'loss': loss_fn,
            }, SAVE_PATH)

# %%
loading = ConvNet(CTYPE)

# %%
ckpnt = torch.load(SAVE_PATH)

# %%
model.load_state_dict(ckpnt['model_state_dict'])

# %%
model
